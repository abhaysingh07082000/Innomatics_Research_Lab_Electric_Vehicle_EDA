# %% [markdown]
# \# **Exploratory Data Analysis on Electric Vehicle**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/sample_data/dataset.csv')

# %%
df.head(2)
# Out:
#    VIN (1-10)  County      City State  Postal Code  Model Year       Make  \
# 0  JTMEB3FV6N  Monroe  Key West    FL        33040        2022     TOYOTA
# 1  1G1RD6E45D   Clark  Laughlin    NV        89029        2013  CHEVROLET
#
#         Model                   Electric Vehicle Type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            42.0
# 1           Clean Alternative Fuel Vehicle Eligible            38.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                   NaN     198968248.0
# 1        0.0                   NaN       5204412.0
#
#               Vehicle Location Electric Utility  2020 Census Tract
# 0    POINT (-81.80023 24.5545)              NaN       1.208797e+10
# 1  POINT (-114.57245 35.16815)              NaN       3.200301e+10

# %%
df.shape
# Out:
# (4427, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4427 entries, 0 to 4426
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         4427 non-null   object
#  1   County                                             4427 non-null   object
#  2   City                                               4427 non-null   object
#  3   State                                              4427 non-null   object
#  4   Postal Code                                        4427 non-null   int64
#  5   Model Year                                         4427 non-null   int64
#  6   Make                                               4426 non-null   object
#  7   Model                                              4426 non-null   object
#  8   Electric Vehicle Type                              4426 non-null   object
# ...

# %% [markdown]
# **From above we can see that 7 columns are of numerical types and 10 colum,ns are of object type**

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                            0
# County                                                0
# City                                                  0
# State                                                 0
# Postal Code                                           0
# Model Year                                            0
# Make                                                  1
# Model                                                 1
# Electric Vehicle Type                                 1
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     1
# Electric Range                                        1
# Base MSRP                                             1
# Legislative District                                 16
# DOL Vehicle ID                                        1
# Vehicle Location                                      2
# Electric Utility                                     26
# 2020 Census Tract                                     1
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (4400, 17)

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#         Postal Code   Model Year  Electric Range      Base MSRP  \
# count   4400.000000  4400.000000     4400.000000    4400.000000
# mean   98266.331818  2019.054773       88.368182    1608.245455
# std      308.744657     2.816015      102.585423   10149.198537
# min    98001.000000  2010.000000        0.000000       0.000000
# 25%    98052.000000  2017.000000        0.000000       0.000000
# 50%    98122.000000  2020.000000       32.000000       0.000000
# 75%    98382.000000  2021.000000      208.000000       0.000000
# max    99403.000000  2023.000000      337.000000  184400.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count           4400.000000    4.400000e+03       4.400000e+03
# mean              29.450455    1.990590e+08       5.303995e+10
# std               14.930948    9.426306e+07       1.669322e+07
# min                1.000000    2.770200e+04       5.300195e+10
# 25%               18.000000    1.487422e+08       5.303301e+10
# ...

# %%
df_numerical=df.select_dtypes(include='number')

# %%
df_numerical.reset_index(drop=True,inplace=True)

# %%
df_numerical.head(2)
# Out:
#    Postal Code  Model Year  Electric Range  Base MSRP  Legislative District  \
# 0        98901        2011            73.0        0.0                  15.0
# 1        98237        2017           238.0        0.0                  39.0
#
#    DOL Vehicle ID  2020 Census Tract
# 0     218972519.0       5.307700e+10
# 1     186750406.0       5.305795e+10

# %%
df_categorical=df.select_dtypes(include='object')

# %%
df_categorical.reset_index(drop=True,inplace=True)

# %%
df_categorical.head(2)
# Out:
#    VIN (1-10)  County      City State       Make    Model  \
# 0  JN1AZ0CP8B  Yakima    Yakima    WA     NISSAN     LEAF
# 1  1G1FW6S08H  Skagit  Concrete    WA  CHEVROLET  BOLT EV
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  \
# 0           Clean Alternative Fuel Vehicle Eligible
# 1           Clean Alternative Fuel Vehicle Eligible
#
#               Vehicle Location        Electric Utility
# 0  POINT (-120.50721 46.60448)              PACIFICORP
# 1   POINT (-121.7515 48.53892)  PUGET SOUND ENERGY INC

# %%
df_numerical.isnull().sum()
# Out:
# Postal Code             0
# Model Year              0
# Electric Range          0
# Base MSRP               0
# Legislative District    0
# DOL Vehicle ID          0
# 2020 Census Tract       0
# dtype: int64

# %%
df_numerical.drop_duplicates(inplace=True)

# %%
df_categorical.drop_duplicates(inplace=True)

# %%
df_categorical.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Vehicle Location                                     0
# Electric Utility                                     0
# dtype: int64

# %%
df_categorical.head(2)
# Out:
#    VIN (1-10)  County      City State       Make    Model  \
# 0  JN1AZ0CP8B  Yakima    Yakima    WA     NISSAN     LEAF
# 1  1G1FW6S08H  Skagit  Concrete    WA  CHEVROLET  BOLT EV
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  \
# 0           Clean Alternative Fuel Vehicle Eligible
# 1           Clean Alternative Fuel Vehicle Eligible
#
#               Vehicle Location        Electric Utility
# 0  POINT (-120.50721 46.60448)              PACIFICORP
# 1   POINT (-121.7515 48.53892)  PUGET SOUND ENERGY INC

# %% [markdown]
# # **UNIVARIATE ANALYSIS**

# %%
df_numerical.describe()
# Out:
#         Postal Code   Model Year  Electric Range      Base MSRP  \
# count   4400.000000  4400.000000     4400.000000    4400.000000
# mean   98266.331818  2019.054773       88.368182    1608.245455
# std      308.744657     2.816015      102.585423   10149.198537
# min    98001.000000  2010.000000        0.000000       0.000000
# 25%    98052.000000  2017.000000        0.000000       0.000000
# 50%    98122.000000  2020.000000       32.000000       0.000000
# 75%    98382.000000  2021.000000      208.000000       0.000000
# max    99403.000000  2023.000000      337.000000  184400.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count           4400.000000    4.400000e+03       4.400000e+03
# mean              29.450455    1.990590e+08       5.303995e+10
# std               14.930948    9.426306e+07       1.669322e+07
# min                1.000000    2.770200e+04       5.300195e+10
# 25%               18.000000    1.487422e+08       5.303301e+10
# ...

# %%
df_numerical.median()
# Out:
# Postal Code             9.812200e+04
# Model Year              2.020000e+03
# Electric Range          3.200000e+01
# Base MSRP               0.000000e+00
# Legislative District    3.300000e+01
# DOL Vehicle ID          1.910460e+08
# 2020 Census Tract       5.303303e+10
# dtype: float64

# %%
df_numerical.mode()
# Out:
#       Postal Code  Model Year  Electric Range  Base MSRP  \
# 0         98052.0      2022.0             0.0        0.0
# 1             NaN         NaN             NaN        NaN
# 2             NaN         NaN             NaN        NaN
# 3             NaN         NaN             NaN        NaN
# 4             NaN         NaN             NaN        NaN
# ...           ...         ...             ...        ...
# 4395          NaN         NaN             NaN        NaN
# 4396          NaN         NaN             NaN        NaN
# 4397          NaN         NaN             NaN        NaN
# 4398          NaN         NaN             NaN        NaN
# 4399          NaN         NaN             NaN        NaN
#
#       Legislative District  DOL Vehicle ID  2020 Census Tract
# 0                     45.0         27702.0       5.306701e+10
# 1                      NaN         63486.0                NaN
# 2                      NaN        111667.0                NaN
# ...

# %%
df_numerical.skew()
# Out:
# Postal Code             1.744317
# Model Year             -0.816222
# Electric Range          0.789421
# Base MSRP               7.300005
# Legislative District   -0.491323
# DOL Vehicle ID          1.127508
# 2020 Census Tract       0.243557
# dtype: float64

# %%
df_numerical.kurtosis()
# Out:
# Postal Code              2.775927
# Model Year              -0.151623
# Electric Range          -0.936805
# Base MSRP               63.943697
# Legislative District    -1.049265
# DOL Vehicle ID           2.459869
# 2020 Census Tract       -0.508036
# dtype: float64

# %%
df_numerical.var()
# Out:
# Postal Code             9.532326e+04
# Model Year              7.929939e+00
# Electric Range          1.052377e+04
# Base MSRP               1.030062e+08
# Legislative District    2.229332e+02
# DOL Vehicle ID          8.885524e+15
# 2020 Census Tract       2.786634e+14
# dtype: float64

# %%
df_numerical.hist(figsize=(14, 10), bins=20, color='skyblue', edgecolor='black')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.kdeplot(df_numerical['Postal Code'], fill=True, color='green')
plt.title('Density Plot of Postal Code')
plt.xlabel('Postal Code')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.kdeplot(df_numerical['Model Year'], fill=True, color='green')
plt.title('Density Plot of Model Year')
plt.xlabel('Model Year')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.kdeplot(df_numerical['Electric Range'], fill=True, color='green')
plt.title('Density Plot of Electric Range')
plt.xlabel('Electric Range')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.kdeplot(df_numerical['Base MSRP'], fill=True, color='green')
plt.title('Density Plot of Base MSRP')
plt.xlabel('Base MSRP')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.figure(figsize=(5, 3))
sns.kdeplot(df_numerical['Legislative District'], fill=True, color='green')
plt.title('Density Plot of Legislative District')
plt.xlabel('Legislative District')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.kdeplot(df_numerical['DOL Vehicle ID'], fill=True, color='green')
plt.title('Density Plot of DOL Vehicle ID')
plt.xlabel('DOL Vehicle ID')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
plt.figure(figsize=(10, 5))
sns.kdeplot(df_numerical['2020 Census Tract'], fill=True, color='green')
plt.title('Density Plot of 2020 Census Tract')
plt.xlabel('2020 Census Tract')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# # **From the above density plots we can say that Postal Code,Electric Range and Base MSRP are left skewed and Model year is right skewed.**

# %%
df_numerical.head(2)
# Out:
#    Postal Code  Model Year  Electric Range  Base MSRP  Legislative District  \
# 0        98901        2011            73.0        0.0                  15.0
# 1        98237        2017           238.0        0.0                  39.0
#
#    DOL Vehicle ID  2020 Census Tract
# 0     218972519.0       5.307700e+10
# 1     186750406.0       5.305795e+10

# %%
plt.figure(figsize=(4,2))
plt.boxplot(df_numerical['Postal Code'], vert=False, patch_artist=True)
plt.title('Box Plot of Postal Code')
plt.xlabel('Postal Code')
plt.show()

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df_numerical['Postal Code'].quantile(0.25)
Q3 = df_numerical['Postal Code'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bound to detect outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove the outliers
df_cleaned_postal = df_numerical[(df_numerical['Postal Code'] >= lower_bound) & (df_numerical['Postal Code'] <= upper_bound)]
print("\n")
print("After Removing outliers from the Postal Code")
print("\n")
plt.figure(figsize=(4,2))
plt.boxplot(df_cleaned_postal['Postal Code'], vert=False, patch_artist=True)
plt.title('Box Plot of Postal Code')
plt.xlabel('Postal Code')
plt.show()
# Out:
# After Removing outliers from the Postal Code

# %%
plt.figure(figsize=(4,2))
plt.boxplot(df_numerical['Model Year'], vert=False, patch_artist=True)
plt.title('Box Plot of Model Year')
plt.xlabel('Model Year')
plt.show()

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df_numerical['Model Year'].quantile(0.25)
Q3 = df_numerical['Model Year'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bound to detect outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove the outliers
df_cleaned_Model_year = df_numerical[(df_numerical['Model Year'] >= lower_bound) & (df_numerical['Model Year']<= upper_bound)]

print("\n")
print("After Removing outliers from the Model Year")
print("\n")

plt.figure(figsize=(4,2))
plt.boxplot(df_cleaned_Model_year['Model Year'], vert=False, patch_artist=True)
plt.title('Box Plot of Model Year')
plt.xlabel('Model Year')
plt.show()
# Out:
# After Removing outliers from the Model Year

# %%
plt.figure(figsize=(4,2))
plt.boxplot(df_numerical['Electric Range'], vert=False, patch_artist=True)
plt.title('Box Plot of Electric Range')
plt.xlabel('Electric Range')
plt.show()

print("\n")
print("We can seee that in Electric range column there is no outlier present")
# Out:
# We can seee that in Electric range column there is no outlier present

# %%
plt.figure(figsize=(4,2))
plt.boxplot(df_numerical['Base MSRP'], vert=False, patch_artist=True)
plt.title('Box Plot of Base MSRP')
plt.xlabel('Base MSRP')
plt.show()

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df_numerical['Base MSRP'].quantile(0.25)
Q3 = df_numerical['Base MSRP'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bound to detect outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove the outliers
df_cleaned_Base_MSRP = df_numerical[(df_numerical['Base MSRP'] >= lower_bound) & (df_numerical['Base MSRP']<= upper_bound)]
print("\n")
print("After Removing outliers from the Base MSRP")
print("\n")
plt.figure(figsize=(4,2))
plt.boxplot(df_cleaned_Base_MSRP['Base MSRP'], vert=False, patch_artist=True)
plt.title('Box Plot of Base MSRP')
plt.xlabel('Base MSRP')
plt.show()
# Out:
# After Removing outliers from the Base MSRP

# %%
plt.figure(figsize=(4,2))
plt.boxplot(df_numerical['Legislative District'], vert=False, patch_artist=True)
plt.title('Box Plot of Legislative District')
plt.xlabel('Legislative District')
plt.show()

print("We can see the at there is no outlier present in the Legislative District")
# Out:
# We can see the at there is no outlier present in the Legislative District

# %%
plt.figure(figsize=(4,2))
plt.boxplot(df_numerical['DOL Vehicle ID'], vert=False, patch_artist=True)
plt.title('Box Plot of DOL Vehicle ID')
plt.xlabel('DOL Vehicle ID')
plt.show()

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df_numerical['DOL Vehicle ID'].quantile(0.25)
Q3 = df_numerical['DOL Vehicle ID'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bound to detect outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove the outliers
df_cleaned_DOL_Vehicle_ID = df_numerical[(df_numerical['DOL Vehicle ID'] >= lower_bound) & (df_numerical['DOL Vehicle ID']<= upper_bound)]
print("\n")
print("After Removing outliers from the DOL Vehicle ID")
print("\n")
plt.figure(figsize=(4,2))
plt.boxplot(df_cleaned_DOL_Vehicle_ID['DOL Vehicle ID'], vert=False, patch_artist=True)
plt.title('Box Plot of DOL Vehicle ID')
plt.xlabel('DOL Vehicle ID')
plt.show()
# Out:
# After Removing outliers from the DOL Vehicle ID

# %%
plt.figure(figsize=(4,2))
plt.boxplot(df_numerical['2020 Census Tract'], vert=False, patch_artist=True)
plt.title('Box Plot of 2020 Census Tract')
plt.xlabel('2020 Census Tract')
plt.show()

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df_numerical['2020 Census Tract'].quantile(0.25)
Q3 = df_numerical['2020 Census Tract'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bound to detect outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove the outliers
df_cleaned_2020_Census_Tract = df_numerical[(df_numerical['2020 Census Tract'] >= lower_bound) & (df_numerical['2020 Census Tract']<= upper_bound)]

print("\n")
print("After Removing outliers from the 2020 Census Tract")
print("\n")

plt.figure(figsize=(4,2))
plt.boxplot(df_cleaned_2020_Census_Tract['2020 Census Tract'], vert=False, patch_artist=True)
plt.title('Box Plot of 2020 Census Tract')
plt.xlabel('2020 Census Tract')
plt.show()
# Out:
# After Removing outliers from the 2020 Census Tract

# %% [markdown]
# Observation-
#
# # We can see from the above only two colum,ns haven't outliers but rest columns have outliers we remove and can see the graphs aftyer removing the outliers from the columns.

# %%
df_categorical.head(2)
# Out:
#    VIN (1-10)  County      City State       Make    Model  \
# 0  JN1AZ0CP8B  Yakima    Yakima    WA     NISSAN     LEAF
# 1  1G1FW6S08H  Skagit  Concrete    WA  CHEVROLET  BOLT EV
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  \
# 0           Clean Alternative Fuel Vehicle Eligible
# 1           Clean Alternative Fuel Vehicle Eligible
#
#               Vehicle Location        Electric Utility
# 0  POINT (-120.50721 46.60448)              PACIFICORP
# 1   POINT (-121.7515 48.53892)  PUGET SOUND ENERGY INC

# %%
df.head(2)
# Out:
#    VIN (1-10)  County      City State  Postal Code  Model Year       Make  \
# 2  JN1AZ0CP8B  Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H  Skagit  Concrete    WA        98237        2017  CHEVROLET
#
#      Model           Electric Vehicle Type  \
# 2     LEAF  Battery Electric Vehicle (BEV)
# 3  BOLT EV  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 2           Clean Alternative Fuel Vehicle Eligible            73.0
# 3           Clean Alternative Fuel Vehicle Eligible           238.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 2        0.0                  15.0     218972519.0
# 3        0.0                  39.0     186750406.0
#
#               Vehicle Location        Electric Utility  2020 Census Tract
# 2  POINT (-120.50721 46.60448)              PACIFICORP       5.307700e+10
# 3   POINT (-121.7515 48.53892)  PUGET SOUND ENERGY INC       5.305795e+10

# %%
import pandas as pd
import plotly.express as px

# %%
df.head(2)
# Out:
#    VIN (1-10)  County      City State  Postal Code  Model Year       Make  \
# 2  JN1AZ0CP8B  Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H  Skagit  Concrete    WA        98237        2017  CHEVROLET
#
#      Model           Electric Vehicle Type  \
# 2     LEAF  Battery Electric Vehicle (BEV)
# 3  BOLT EV  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 2           Clean Alternative Fuel Vehicle Eligible            73.0
# 3           Clean Alternative Fuel Vehicle Eligible           238.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 2        0.0                  15.0     218972519.0
# 3        0.0                  39.0     186750406.0
#
#               Vehicle Location        Electric Utility  2020 Census Tract
# 2  POINT (-120.50721 46.60448)              PACIFICORP       5.307700e+10
# 3   POINT (-121.7515 48.53892)  PUGET SOUND ENERGY INC       5.305795e+10

# %%
# !pip install --upgrade bar-chart-race
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.4 MB/s eta 0:00:00
# ...

# %%
import bar_chart_race as bcr

# %%
ev_counts = df.groupby(['Model Year', 'Make']).size().reset_index(name='Count')

# Step 2: Pivot the data for the bar-chart-race
pivot_df = ev_counts.pivot(index='Make', columns='Model Year', values='Count').fillna(0)

# Step 3: Create the racing bar plot
bcr.bar_chart_race(df=pivot_df,
                   filename='ev_makes_race.mp4',  # Save as an mp4 file
                   title='Year Wise Count of Electric Vehicles by Make',
                   label_bars=True,
                   sort='desc',  # Sort bars in descending order
                   n_bars=10,  # Number of bars to show
                   fixed_order=False,
                   steps_per_period=10,
                   period_length=1000,
                   figsize=(6, 4),  # Figure size
                   bar_label_size=12,  # Size of bar labels
                   title_size=16,  # Size of title
                   )

# %%
from IPython.display import HTML

# Replace 'your_video_url.mp4' with the actual URL
video_url = '/content/ev_makes_race.mp4'
HTML(f'<video width="640" height="480" controls><source src="{video_url}" type="video/mp4"></video>')
# Out:
# <video width="640" height="480" controls><source src="/content/ev_makes_race.mp4" type="video/mp4"></video>

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(2)
# Out:
#    VIN (1-10)  County      City State  Postal Code  Model Year       Make  \
# 2  JN1AZ0CP8B  Yakima    Yakima    WA        98901        2011     NISSAN
# 3  1G1FW6S08H  Skagit  Concrete    WA        98237        2017  CHEVROLET
#
#      Model           Electric Vehicle Type  \
# 2     LEAF  Battery Electric Vehicle (BEV)
# 3  BOLT EV  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 2           Clean Alternative Fuel Vehicle Eligible            73.0
# 3           Clean Alternative Fuel Vehicle Eligible           238.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 2        0.0                  15.0     218972519.0
# 3        0.0                  39.0     186750406.0
#
#               Vehicle Location        Electric Utility  2020 Census Tract
# 2  POINT (-120.50721 46.60448)              PACIFICORP       5.307700e+10
# 3   POINT (-121.7515 48.53892)  PUGET SOUND ENERGY INC       5.305795e+10

# %% [markdown]
# number of EV vehicles based on location

# %%
count=df['Electric Vehicle Type'].value_counts()
count.head()
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            3393
# Plug-in Hybrid Electric Vehicle (PHEV)    1007
# Name: count, dtype: int64

# %%
! pip install plotly

# %%
import plotly.express as px

# %%
ev_count_by_state = df.groupby('State').size().reset_index(name='Number_of_EV_Vehicles')
ev_count_by_state
# Out:
#   State  Number_of_EV_Vehicles
# 0    WA                   4400

# %%
import pandas as pd
import plotly.express as px

# Count the number of EVs per postal code
ev_count_by_postal = df['Postal Code'].value_counts().reset_index()
ev_count_by_postal.columns = ['Postal Code', 'EV_Count']

# Merge the count with the original dataframe to get location data
df_merged = df.merge(ev_count_by_postal, on='Postal Code')

# Extract latitude and longitude from the 'Vehicle Location' column
df_merged['Longitude'] = df_merged['Vehicle Location'].str.extract('POINT \(([-\d.]+) ')
df_merged['Latitude'] = df_merged['Vehicle Location'].str.extract(' ([-\d.]+)\)')

# Convert to numeric
df_merged['Longitude'] = pd.to_numeric(df_merged['Longitude'])
df_merged['Latitude'] = pd.to_numeric(df_merged['Latitude'])

# Create the scatter plot on a map
fig = px.scatter_mapbox(df_merged,
                        lat='Latitude',
                        lon='Longitude',
                        color='EV_Count',
                        size='EV_Count',
                        hover_name='Postal Code',
                        hover_data=['City', 'State', 'EV_Count'],
                        color_continuous_scale="Viridis",
                        size_max=15,
                        zoom=3,
                        title="Number of Electric Vehicles by Postal Code")

fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

# Save the plot as an HTML file
fig.write_html("ev_postal_code_map.html")

fig.show()

print("Scatter map based on postal codes has been created and saved as 'ev_postal_code_map.html'.")
print("\
Top 10 postal codes by EV count:")
print(ev_count_by_postal.head(10).to_string(index=False))

# Display some statistics
print("\
Total number of unique postal codes:", len(ev_count_by_postal))
print("Average number of EVs per postal code:", round(ev_count_by_postal['EV_Count'].mean(), 2))
print("Median number of EVs per postal code:", ev_count_by_postal['EV_Count'].median())
print("Maximum number of EVs in a single postal code:", ev_count_by_postal['EV_Count'].max())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
